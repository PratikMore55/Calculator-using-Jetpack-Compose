# %% [markdown]
# <a href="https://colab.research.google.com/github/PratikMore55/Calculator-using-Jetpack-Compose/blob/master/test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="AnCQtSUUaNVf06eUIETI")
project = rf.workspace("pratik-qrole").project("test-lxpju")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.8
#     Uninstalling idna-3.8:
#       Successfully uninstalled idna-3.8
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# [WARNING] we noticed you are downloading a `yolov8` datasets but you don't have `ultralytics` installed. Roboflow `.deploy` supports only models trained with `ultralytics==8.0.196`, to intall it `pip install ultralytics==8.0.196`.
# ...
# Extracting Dataset Version Zip to test-1 in yolov8:: 100%|██████████| 2026/2026 [00:00<00:00, 2519.80it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 770.8 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.6/871.6 kB 6.7 MB/s eta 0:00:00
# ...

# %%
# !yolo task = detect mode = train model = yolov8n.pt data={dataset.location}/data.yaml epochs=2 imgsz=800
# Out:
# Ultralytics YOLOv8.2.83 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
from IPython.display import Image

# %%
Image(filename = f'/content/runs/detect/train5/confusion_matrix.png', width = 500)

# %%
# !yolo task = detect mode = val model = /content/runs/detect/train5/weights/best.pt data = {dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.2.83 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,008,183 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/test-1/valid/labels.cache... 81 images, 0 backgrounds, 0 corrupt: 100% 81/81 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 4, len(boxes) = 193. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 6/6 [00:46<00:00,  7.80s/it]
#                    all         81        193      0.465      0.265      0.292       0.17
#                    ABS         20         20      0.315        0.6      0.334      0.218
#                 Airbag         12         12      0.731     0.0833      0.277      0.194
# ...

# %%
Image(filename = f'/content/runs/detect/train5/results.png', width = 500)

# %%
# !yolo task = detect mode = predict model = /content/runs/detect/train5/weights/best.pt conf = 0.25 source={dataset.location}/test/images
# Out:
# Ultralytics YOLOv8.2.83 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3,008,183 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/41 /content/test-1/test/images/Airbag10_jpeg.rf.9cfde70cf6516bc1d9563e075bedc186.jpg: 800x800 (no detections), 448.4ms
# image 2/41 /content/test-1/test/images/Img-10-_jpg.rf.cd7af0acfaf92dd110e731c6b7ab9a9f.jpg: 800x800 1 EngineWarning, 380.6ms
# image 3/41 /content/test-1/test/images/Img-23-_jpg.rf.04f2982528026c20b36d8046923c6bae.jpg: 800x800 2 EngineWarnings, 326.0ms
# image 4/41 /content/test-1/test/images/Img-4-_jpg.rf.4bc11e7bbb1fb7a17a0d03a551216cf7.jpg: 800x800 1 EngineWarning, 326.6ms
# image 5/41 /content/test-1/test/images/Img-41-_jpg.rf.03ea488aeea5fea508fc8ba2f0b97743.jpg: 800x800 1 EngineWarning, 330.4ms
# image 6/41 /content/test-1/test/images/Img-49-_jpg.rf.ec48bf219b3a92baeadbb06c6e0132a4.jpg: 800x800 2 EngineWarnings, 1 LowFuel, 320.3ms
# ...
